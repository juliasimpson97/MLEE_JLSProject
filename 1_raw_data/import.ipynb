# %%
import pandas as pd
import xarray as xr
import numpy as np
from matplotlib import pyplot as plt

# %%
possible_path = '/local/data/artemis/workspace/vbennington/SOCAT_ML/pCO2_DIC_Tak/data/processed/data_clean_2D_mon_1x1_198201-201912.pkl'
ds_mod = xr.open_dataset(possible_path)

# %%
url_SST = #'https://psl.noaa.gov/data/gridded/data.noaa.oisst.v2.highres.html'
url_SSTanomaly = #'https://psl.noaa.gov/data/gridded/data.noaa.oisst.v2.highres.html'
url_ICE = #'https://psl.noaa.gov/data/gridded/data.noaa.oisst.v2.highres.html'
url_SSS = #'https://www.metoffice.gov.uk/hadobs/en4/'
url_xCO2 = #'https://gml.noaa.gov/ccgg/mbl/'
url_chlA = #'https://www.globcolour.info'
url_chlAanomaly = #'https://www.globcolour.info'
url_MLD = #'https://cerweb.ifremer.fr/deboyer/mld/home.php'
url_pCO2 = 'https://www.ncei.noaa.gov/data/oceans/ncei/ocads/data/0253659/SOCATv2022_Gridded_Dat/SOCATv2022_tracks_gridded_monthly.csv' #MONTHLY 'https://www.socat.info'

dayofyear =
nvector =

# %%
df = pd.read_csv('https://www.ncei.noaa.gov/data/oceans/ncei/ocads/data/0253659/SOCATv2022_Gridded_Dat/SOCATv2022_tracks_gridded_monthly.csv') # "Missing values are represented as -1.E+34"
df.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In [15], line 1
# ----> 1 df = pd.read_csv('https://www.ncei.noaa.gov/data/oceans/ncei/ocads/data/0253659/SOCATv2022_Gridded_Dat/SOCATv2022_tracks_gridded_monthly.csv') # "Missing values are represented as -1.E+34"
#       2 df.head()
#
# File ~/.conda/envs/fromML/lib/python3.9/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/.conda/envs/fromML/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
pd.read_csv?
# Out:
# Signature:
# pd.read_csv(
#     filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]',
#     *,
#     sep: 'str | None | lib.NoDefault' = <no_default>,
#     delimiter: 'str | None | lib.NoDefault' = None,
#     header: "int | Sequence[int] | None | Literal['infer']" = 'infer',
#     names: 'Sequence[Hashable] | None | lib.NoDefault' = <no_default>,
#     index_col: 'IndexLabel | Literal[False] | None' = None,
#     usecols=None,
#     squeeze: 'bool | None' = None,
#     prefix: 'str | lib.NoDefault' = <no_default>,
#     mangle_dupe_cols: 'bool' = True,
#     dtype: 'DtypeArg | None' = None,
#     engine: 'CSVEngine | None' = None,
#     converters=None,
#     true_values=None,
#     false_values=None,
#     skipinitialspace: 'bool' = False,
#     skiprows=None,
#     skipfooter: 'int' = 0,
#     nrows: 'int | None' = None,
#     na_values=None,
#     keep_default_na: 'bool' = True,
#     na_filter: 'bool' = True,
#     verbose: 'bool' = False,
# ...
